# %% [markdown]
# # Time series analysis for a single location
#
# For a single location the following analysis are made:
#
# - Autocorrelation and cross-correlation with precipitation
# - STL decomposition
# - Dynamic factor analysis for network centrality and precipitation

# %%
from matplotlib import pyplot as plt

# %%
from pyveg.src.data_analysis_utils import *
# %matplotlib inline

# %% [markdown]
# Helper functions:

# %%
def resample_time_series(df, col_name="offset50",period = "D"):
    """
    Resample and interpolate a time series dataframe so we have one row
    per day (useful for FFT)

    Parameters
    ----------
    df: DataFrame with date as index
    col_name: string, identifying the column we will pull out

    Returns
    -------
    new_series: pandas Series with datetime index, and one column, one row per day
    """
    series = df[col_name]
    # just in case the index isn't already datetime type
    series.index = pd.to_datetime(series.index)

    # resample to get one row per day
    rseries = series.resample(period).mean()
    
    new_series = rseries.interpolate()

    return new_series

# %%
def read_file_create_ts(input_dir):

    output_dir = os.path.join(input_dir, 'analysis')

    # check file exists
    json_summary_path = os.path.join(input_dir, 'results_summary.json')
    dfs = variable_read_json_to_dataframe(json_summary_path)
    
    
    dfs = drop_veg_outliers(dfs, sigmas=3) # not convinced this is really helping much

    # drop outliers and smooth results
    time_series_dfs = make_time_series(smooth_veg_data(dfs.copy(), n=5)) # increase smoothing with n>5

    #time_series_dfs = make_time_series(dfs)
    
    offsets = resample_time_series(time_series_dfs['COPERNICUS/S2'], col_name="offset50_smooth_mean",period="M")
    precipitation = resample_time_series(time_series_dfs['ECMWF/ERA5/MONTHLY'], col_name="total_precipitation",period="M")

    precipitation = precipitation[precipitation.index.isin(offsets.index)]
    return offsets, precipitation

# %%
input_dir_spots = '/Users/crangelsmith/PycharmProjects/monitoring-ecosystem-resilience/output/Copernicus_Spots_2016_2020/__2020-03-09_16-46-33/'
input_dir_laberynths = '/Users/crangelsmith/PycharmProjects/monitoring-ecosystem-resilience/output/labyrinths/'
input_dir_gaps = '/Users/crangelsmith/PycharmProjects/monitoring-ecosystem-resilience/output/gaps/'

# %% [markdown]
# ## Autocorrelations

# %%
offsets, precipitation = read_file_create_ts(input_dir_spots)

print (precipitation.shape)
# Out:
# (48,)

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(precipitation)
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(offsets)
plt.show()

# %% [markdown]
# ## Cross-correlations between network centrality values and precipitation

# %%
fig, ax1 = plt.subplots(1, 1, sharex=True)

ax1.xcorr(precipitation, offsets, usevlines=True, maxlags=24, normed=True, lw=1.5)
ax1.grid(True)


plt.show()

# %% [markdown]
# ## STL decomposition
#
# ### Precipitation

# %%
from pandas.plotting import register_matplotlib_converters
import seaborn as sns

register_matplotlib_converters()
sns.set_style('darkgrid')
plt.rc('figure',figsize=(18,12))
plt.rc('font',size=13)

from statsmodels.tsa.seasonal import STL

stl = STL(precipitation, period=12)
res = stl.fit()
fig = res.plot()

ax_list = fig.axes

for ax in ax_list:
    ax.set_xticklabels(precipitation.index, rotation = 45, va="center", position=(0,-0.28))

# %% [markdown]
# ### Network centrality values

# %%
from pandas.plotting import register_matplotlib_converters
import seaborn as sns

register_matplotlib_converters()
sns.set_style('darkgrid')
plt.rc('figure',figsize=(18,12))
plt.rc('font',size=13)

from statsmodels.tsa.seasonal import STL

stl = STL(offsets, period=12)

res = stl.fit()
fig = res.plot()

ax_list = fig.axes

for ax in ax_list:
    ax.set_xticklabels(offsets.index, rotation = 45, va="center", position=(0,-0.28))

# %% [markdown]
# ## Dynamic factor analysis
#
# ### Network centrality and precipitation with seasonality

# %%
import statsmodels.api as sm

#df1 = pd.DataFrame(precipitation.diff(12))
#df2 = pd.DataFrame(offsets.diff(12))

df1 = pd.DataFrame(precipitation)
df2 = pd.DataFrame(offsets)



endog = df1.join(df2, how='outer')
endog.dropna(inplace = True)

endog['total_precipitation'] = (endog['total_precipitation'] - endog['total_precipitation'].mean()) / endog['total_precipitation'].std()
endog['offset50_smooth_mean'] = (endog['offset50_smooth_mean'] - endog['offset50_smooth_mean'].mean()) / endog['offset50_smooth_mean'].std()
# Get the endogenous data

# Create the model
mod = sm.tsa.DynamicFactor(endog, k_factors=1, factor_order=1, error_order=1)
initial_res = mod.fit(method='powell', disp=False)
res = mod.fit(initial_res.params, disp=False)
# Out:
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
print(res.summary(separate_params=False))
# Out:
#                                           Statespace Model Results
# ===========================================================================================================
# Dep. Variable:     ['total_precipitation', 'offset50_smooth_mean']   No. Observations:                   48
# Model:                           DynamicFactor(factors=1, order=1)   Log Likelihood                 -96.489
#                                                     + AR(1) errors   AIC                            206.979
# Date:                                             Tue, 07 Apr 2020   BIC                            220.077
# Time:                                                     13:30:30   HQIC                           211.929
# Sample:                                                 01-31-2016
#                                                       - 12-31-2019
# Covariance Type:                                               opg
# ======================================================================================================================
#                                                          coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# loading.f1.total_precipitation                         0.7805      0.028     28.283      0.000       0.726       0.835
# loading.f1.offset50_smooth_mean                        0.1469      0.027      5.496      0.000       0.095       0.199
# sigma2.total_precipitation                          1.261e-15    1.9e-09   6.64e-07      1.000   -3.72e-09    3.72e-09
# sigma2.offset50_smooth_mean                            0.2974      0.010     29.136      0.000       0.277       0.317
# L1.f1.f1                                               0.6038      0.020     29.708      0.000       0.564       0.644
# L1.e(total_precipitation).e(total_precipitation)      -1.0000      0.002   -471.047      0.000      -1.004      -0.996
# L1.e(offset50_smooth_mean).e(offset50_smooth_mean)     0.7885      0.006    130.787      0.000       0.777       0.800
# ===================================================================================
# Ljung-Box (Q):               80.87, 100.01   Jarque-Bera (JB):          69.29, 0.07
# Prob(Q):                        0.00, 0.00   Prob(JB):                   0.00, 0.97
# Heteroskedasticity (H):         4.30, 5.07   Skew:                      1.56, -0.01
# Prob(H) (two-sided):            0.01, 0.00   Kurtosis:                   7.99, 2.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.92e+17. Standard errors may be unstable.

# %%
fig, ax = plt.subplots(figsize=(13,3))

# Plot the factor
dates = endog.index._mpl_repr()
ax.plot(dates, res.factors.filtered[0], label='Factor')
ax.legend()

# %%
res.plot_coefficients_of_determination(figsize=(8,2));

# %%
res.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# ### Network centrality and precipitation without seasonality

# %%
df1 = pd.DataFrame(precipitation.diff(12))
df2 = pd.DataFrame(offsets.diff(12))

endog = df1.join(df2, how='outer')
endog.dropna(inplace = True)

endog['total_precipitation'] = (endog['total_precipitation'] - endog['total_precipitation'].mean()) / endog['total_precipitation'].std()
endog['offset50_smooth_mean'] = (endog['offset50_smooth_mean'] - endog['offset50_smooth_mean'].mean()) / endog['offset50_smooth_mean'].std()
# Get the endogenous data

# Create the model
mod = sm.tsa.DynamicFactor(endog, k_factors=1, factor_order=1, error_order=1)
initial_res = mod.fit(method='powell', disp=False)
res = mod.fit(initial_res.params, disp=False)
print(res.summary(separate_params=False))
# Out:
#                                           Statespace Model Results
# ===========================================================================================================
# Dep. Variable:     ['total_precipitation', 'offset50_smooth_mean']   No. Observations:                   36
# Model:                           DynamicFactor(factors=1, order=1)   Log Likelihood                 -84.032
#                                                     + AR(1) errors   AIC                            182.063
# Date:                                             Tue, 07 Apr 2020   BIC                            193.148
# Time:                                                     13:30:32   HQIC                           185.932
# Sample:                                                 01-31-2017
#                                                       - 12-31-2019
# Covariance Type:                                               opg
# ======================================================================================================================
#                                                          coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# loading.f1.total_precipitation                         0.6097      0.610      0.999      0.318      -0.586       1.806
# loading.f1.offset50_smooth_mean                        0.0409      0.305      0.134      0.893      -0.557       0.638
# sigma2.total_precipitation                             0.2884      0.732      0.394      0.694      -1.147       1.724
# sigma2.offset50_smooth_mean                            0.4068      0.131      3.115      0.002       0.151       0.663
# L1.f1.f1                                               0.5413      0.599      0.904      0.366      -0.633       1.715
# L1.e(total_precipitation).e(total_precipitation)      -0.5842      0.880     -0.664      0.507      -2.309       1.141
# L1.e(offset50_smooth_mean).e(offset50_smooth_mean)     0.7836      0.120      6.538      0.000       0.549       1.019
# ===================================================================================
# Ljung-Box (Q):                12.39, 56.33   Jarque-Bera (JB):         174.76, 0.46
# Prob(Q):                        1.00, 0.01   Prob(JB):                   0.00, 0.80
# Heteroskedasticity (H):         7.68, 1.30   Skew:                      2.28, -0.11
# Prob(H) (two-sided):            0.00, 0.66   Kurtosis:                  12.78, 2.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fig, ax = plt.subplots(figsize=(13,3))

# Plot the factor
dates = endog.index._mpl_repr()
ax.plot(dates, res.factors.smoothed[0], label='Factor')
ax.legend()

# %%
res.plot_coefficients_of_determination(figsize=(8,2));

# %%
res.plot_diagnostics(figsize=(18, 8))
plt.show()

# %% [markdown]
# ## Comments:
#
# - 6 and 12 month cycles of seasonality
# - 3 month lag between precipitation and network centrality values
# - STL decomposition fit with correlated residuals, not great.
# - Factor fitted with precipitation data and network centrality significant for data with seasonality. Factor follows precipitation pattern.
# - By removing seasonality no significant common factor fitted.
# - Both cases the goodness of the fit is not great either.
